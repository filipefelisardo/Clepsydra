# %%
# Importar bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# Carregar os dados do arquivo Excel
file_path = '/content/precipitacoes_mensais_1999.xlsx'
df = pd.read_excel(file_path)

# Verificar as primeiras linhas do dataframe para entender a estrutura dos dados
print(df.head())

# Assumindo que a primeira coluna contém os meses e as outras colunas são estações
# Ajustar conforme a estrutura real dos seus dados
df.set_index(df.columns[0], inplace=True)

# Verificar o índice e colunas do dataframe
print(df.index)
print(df.columns)

# Plotar gráficos de precipitação para cada estação
for column in df.columns:
    plt.figure(figsize=(10, 5))
    plt.bar(df.index, df[column])
    plt.title(f'Precipitação Mensal em {column}')
    plt.xlabel('Meses')
    plt.ylabel('Precipitação (mm)')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
#                DATA  BARRAGEM DE ODIVELAS (24I/03C)  \
# 0  01/01/1999 09:00                            80.5
# 1  01/02/1999 09:00                            10.5
# 2  01/03/1999 09:00                            58.8
# 3  01/04/1999 09:00                            36.7
# 4  01/05/1999 09:00                            31.1
#
#    BARRAGEM DE PEGO DO ALTAR (23G/01C)  BARRAGEM DO DIVOR (21J/03C)  \
# 0                                 77.8                         80.6
# 1                                 19.9                         19.6
# 2                                 67.0                         62.9
# 3                                 38.9                         18.2
# 4                                 38.3                         39.0
#
#    BARRAGEM DO ROXO (26I/02C)  GRÂNDOLA (24F/01C)  \
# 0                        66.7                84.9
# 1                         7.6                14.8
# 2                        54.1                77.9
# 3                        43.9                28.5
# 4                        35.4                54.0
#
#    HERDADE DAS RASCAS (26J/05C)  MOINHOLA (22F/03C)
# 0                          67.8                74.1
# 1                          21.5                20.0
# 2                          77.7                55.2
# 3                          37.0                63.5
# 4                          29.0                45.5
# Index(['01/01/1999 09:00', '01/02/1999 09:00', '01/03/1999 09:00',
#        '01/04/1999 09:00', '01/05/1999 09:00', '01/06/1999 09:00',
#        '01/07/1999 09:00', '01/08/1999 09:00', '01/09/1999 09:00',
#        '01/10/1999 09:00', '01/11/1999 09:00', '01/12/1999 09:00'],
#       dtype='object', name='DATA')
# Index(['BARRAGEM DE ODIVELAS (24I/03C)', 'BARRAGEM DE PEGO DO ALTAR (23G/01C)',
#        'BARRAGEM DO DIVOR (21J/03C)', 'BARRAGEM DO ROXO (26I/02C)',
#        'GRÂNDOLA (24F/01C)', 'HERDADE DAS RASCAS (26J/05C)',
#        'MOINHOLA (22F/03C)'],
#       dtype='object')
