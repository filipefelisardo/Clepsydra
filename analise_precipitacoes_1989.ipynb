# %%
# Importar bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# Carregar os dados do arquivo Excel
file_path = '/content/precipitacoes_mensais_1989.xlsx'
df = pd.read_excel(file_path)

# Verificar as primeiras linhas do dataframe para entender a estrutura dos dados
print(df.head())

# Assumindo que a primeira coluna contém os meses e as outras colunas são estações
# Ajustar conforme a estrutura real dos seus dados
df.set_index(df.columns[0], inplace=True)

# Verificar o índice e colunas do dataframe
print(df.index)
print(df.columns)

# Plotar gráficos de precipitação para cada estação
for column in df.columns:
    plt.figure(figsize=(10, 5))
    plt.bar(df.index, df[column])
    plt.title(f'Precipitação Mensal em {column}')
    plt.xlabel('Meses')
    plt.ylabel('Precipitação (mm)')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
#                DATA  ALCOENTRE (18D/03C)  ANSIÃO (14G/01C)  \
# 0  01/01/1989 09:00                 69.5              51.2
# 1  01/02/1989 09:00                 82.8             136.4
# 2  01/03/1989 09:00                 69.8              41.3
# 3  01/04/1989 09:00                 86.6             132.8
# 4  01/05/1989 09:00                 93.6             108.3
#
#    ASSEICEIRA (18D/01C)  BARRAGEM DE MONTARGIL (19H/02C)  \
# 0                  57.0                             35.0
# 1                  84.7                             54.4
# 2                  67.7                             26.0
# 3                  84.5                             80.0
# 4                 105.1                             56.9
#
#    BARRAGEM DE ODIVELAS (24I/03C)  BARRAGEM DE PEGO DO ALTAR (23G/01C)  \
# 0                            35.1                                 32.7
# 1                            32.0                                 54.4
# 2                            19.1                                 13.5
# 3                           106.1                                 88.7
# 4                            69.6                                 95.1
#
#    BARRAGEM DE VALE DO GAIO (24H/02C)  BARRAGEM DO DIVOR (21J/03C)  \
# 0                                36.7                         37.8
# 1                                39.9                         47.5
# 2                                21.0                         28.0
# 3                                87.8                         73.7
# 4                               100.5                         82.7
#
#    BARRAGEM DO MARANHÃO (19J/04C)  ...  CABEÇO MONTEIRO (14N/04C)  \
# 0                            37.4  ...                       25.9
# 1                            43.0  ...                       49.1
# 2                            36.7  ...                       31.1
# 3                            70.1  ...                       32.0
# 4                            85.8  ...                       63.1
#
#    COMPORTA (23E/01C)  GRÂNDOLA (24F/01C)  LARANJAL (PONTE SÔR) (18I/01C)  \
# 0                43.8                36.3                            49.2
# 1                48.2                77.3                            67.4
# 2                23.1                17.7                            36.1
# 3                93.3               101.5                            56.6
# 4                47.8                87.0                           117.7
#
#    MECA (19C/08C)  MOINHOLA (22F/03C)  MONTE DA CAPARICA (22B/01C)  \
# 0            59.3                41.9                         67.6
# 1            62.6                54.2                         67.3
# 2            47.1                27.5                         50.2
# 3           102.6                82.1                        109.3
# 4           120.4               157.4                         38.6
#
#    PEDROGÃO (16F/04C)  SANTARÉM (ESA) (18E/01C)  \
# 0                43.3                      30.9
# 1               110.4                      57.0
# 2                32.5                      32.2
# 3                92.4                      72.9
# 4                91.5                      54.1
#
#    VILA FRANCA DE XIRA (LEZÍRIA) (20D/01C)
# 0                                     59.0
# 1                                     55.5
# 2                                     35.5
# 3                                     63.5
# 4                                    106.7
#
# [5 rows x 22 columns]
# Index(['01/01/1989 09:00', '01/02/1989 09:00', '01/03/1989 09:00',
#        '01/04/1989 09:00', '01/05/1989 09:00', '01/06/1989 09:00',
#        '01/07/1989 09:00', '01/08/1989 09:00', '01/09/1989 09:00',
#        '01/10/1989 09:00', '01/11/1989 09:00', '01/12/1989 09:00'],
#       dtype='object', name='DATA')
# Index(['ALCOENTRE (18D/03C)', 'ANSIÃO (14G/01C)', 'ASSEICEIRA (18D/01C)',
#        'BARRAGEM DE MONTARGIL (19H/02C)', 'BARRAGEM DE ODIVELAS (24I/03C)',
#        'BARRAGEM DE PEGO DO ALTAR (23G/01C)',
#        'BARRAGEM DE VALE DO GAIO (24H/02C)', 'BARRAGEM DO DIVOR (21J/03C)',
#        'BARRAGEM DO MARANHÃO (19J/04C)', 'BARRAGEM DO ROXO (26I/02C)',
#        'BARRAGEM MONTE DA ROCHA (27H/02C)', 'CABEÇO MONTEIRO (14N/04C)',
#        'COMPORTA (23E/01C)', 'GRÂNDOLA (24F/01C)',
#        'LARANJAL (PONTE SÔR) (18I/01C)', 'MECA (19C/08C)',
#        'MOINHOLA (22F/03C)', 'MONTE DA CAPARICA (22B/01C)',
#        'PEDROGÃO (16F/04C)', 'SANTARÉM (ESA) (18E/01C)',
#        'VILA FRANCA DE XIRA (LEZÍRIA) (20D/01C)'],
#       dtype='object')
