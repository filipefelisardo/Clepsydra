# %%
# Importar bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# Carregar os dados do arquivo Excel
file_path = '/content/precipitacoes_mensais_2019.xlsx'
df = pd.read_excel(file_path)

# Verificar as primeiras linhas do dataframe para entender a estrutura dos dados
print(df.head())

# Assumindo que a primeira coluna contém os meses e as outras colunas são estações
# Ajustar conforme a estrutura real dos seus dados
df.set_index(df.columns[0], inplace=True)

# Verificar o índice e colunas do dataframe
print(df.index)
print(df.columns)

# Plotar gráficos de precipitação para cada estação
for column in df.columns:
    plt.figure(figsize=(10, 5))
    plt.bar(df.index, df[column])
    plt.title(f'Precipitação Mensal em {column}')
    plt.xlabel('Meses')
    plt.ylabel('Precipitação (mm)')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
#                DATA  ABRANTES (17H/01C)  ALCANENA (17F/02CG)  \
# 0  01/01/2019 09:00                31.2                 23.9
# 1  01/02/2019 09:00                30.9                 47.2
# 2  01/03/2019 09:00                13.8                 40.9
# 3  01/04/2019 09:00                 0.4                100.4
# 4  01/05/2019 09:00                 0.0                 14.7
#
#    ALCOENTRE (18D/03C)  ALCÁÇOVAS (23I/01C)  BARRAGEM DE CAMPILHAS (26F/02C)  \
# 0                  NaN                  NaN                              NaN
# 1                  NaN                  NaN                              NaN
# 2                  NaN                  NaN                              NaN
# 3                  0.9                  NaN                             49.5
# 4                  0.4                  NaN                              1.7
#
#    BARRAGEM DE MAGOS (20E/01C)  BARRAGEM DE ODIVELAS (24I/03C)  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                         44.1                             NaN
# 3                         64.8                             NaN
# 4                          NaN                             NaN
#
#    BARRAGEM DE PEGO DO ALTAR (23G/01C)  BARRAGEM DE VALE DO GAIO (24H/02C)  \
# 0                                  0.3                                 3.2
# 1                                  0.1                                11.3
# 2                                  0.0                                 0.0
# 3                                  0.2                                 0.0
# 4                                  0.0                                 0.0
#
#    ...  MARIANOS (18G/03UC)  MECA (19C/08C)  MONTE DA CAPARICA (22B/01C)  \
# 0  ...                 61.3             NaN                         25.1
# 1  ...                 44.2             NaN                          5.3
# 2  ...                  0.6             1.6                          NaN
# 3  ...                  0.0            14.1                         24.0
# 4  ...                  0.0             9.0                          NaN
#
#    PEDROGÃO (16F/04C)  PENEDOS DE ALENQUER (19C/04C)  \
# 0                35.0                           22.6
# 1                52.0                           15.5
# 2                47.1                            4.8
# 3               114.1                           81.1
# 4                19.4                           18.4
#
#    PROENÇA-A-NOVA (15J/01UC)  SANTARÉM (ESA) (18E/01C)  \
# 0                       35.1                       NaN
# 1                       63.7                       NaN
# 2                       38.4                       NaN
# 3                      143.1                       NaN
# 4                       18.1                       NaN
#
#    SÃO JULIÃO DO TOJAL (20C/01C)  VIANA DO ALENTEJO (24I/01C)  \
# 0                           67.4                         30.7
# 1                           17.4                         34.2
# 2                           22.8                         16.7
# 3                           46.7                          0.1
# 4                            1.2                          0.3
#
#    VILA FRANCA DE XIRA (LEZÍRIA) (20D/01C)
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 25 columns]
# Index(['01/01/2019 09:00', '01/02/2019 09:00', '01/03/2019 09:00',
#        '01/04/2019 09:00', '01/05/2019 09:00', '01/06/2019 09:00',
#        '01/07/2019 09:00', '01/08/2019 09:00', '01/09/2019 09:00',
#        '01/10/2019 09:00', '01/11/2019 09:00', '01/12/2019 09:00'],
#       dtype='object', name='DATA')
# Index(['ABRANTES (17H/01C)', 'ALCANENA (17F/02CG)', 'ALCOENTRE (18D/03C)',
#        'ALCÁÇOVAS (23I/01C)', 'BARRAGEM DE CAMPILHAS (26F/02C)',
#        'BARRAGEM DE MAGOS (20E/01C)', 'BARRAGEM DE ODIVELAS (24I/03C)',
#        'BARRAGEM DE PEGO DO ALTAR (23G/01C)',
#        'BARRAGEM DE VALE DO GAIO (24H/02C)', 'CERNACHE DE BONJARDIM (15H/01C)',
#        'COMPORTA (23E/01C)', 'GRÂNDOLA (24F/01C)',
#        'LARANJAL (PONTE SÔR) (18I/01C)', 'LOUSA (20B/03C)',
#        'MARIANOS (18G/03UC)', 'MECA (19C/08C)', 'MONTE DA CAPARICA (22B/01C)',
#        'PEDROGÃO (16F/04C)', 'PENEDOS DE ALENQUER (19C/04C)',
#        'PROENÇA-A-NOVA (15J/01UC)', 'SANTARÉM (ESA) (18E/01C)',
#        'SÃO JULIÃO DO TOJAL (20C/01C)', 'VIANA DO ALENTEJO (24I/01C)',
#        'VILA FRANCA DE XIRA (LEZÍRIA) (20D/01C)'],
#       dtype='object')
