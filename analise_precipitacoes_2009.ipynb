# %%
# Importar bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# Carregar os dados do arquivo Excel
file_path = '/content/precipitacoes_mensais_2009.xlsx'
df = pd.read_excel(file_path)

# Verificar as primeiras linhas do dataframe para entender a estrutura dos dados
print(df.head())

# Assumindo que a primeira coluna contém os meses e as outras colunas são estações
# Ajustar conforme a estrutura real dos seus dados
df.set_index(df.columns[0], inplace=True)

# Verificar o índice e colunas do dataframe
print(df.index)
print(df.columns)

# Plotar gráficos de precipitação para cada estação
for column in df.columns:
    plt.figure(figsize=(10, 5))
    plt.bar(df.index, df[column])
    plt.title(f'Precipitação Mensal em {column}')
    plt.xlabel('Meses')
    plt.ylabel('Precipitação (mm)')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
#                DATA  ABRANTES (17H/01C)  ALBUFEIRA DE PEGO DO ALTAR (23G/01F)  \
# 0  01/01/2009 09:00                85.1                                   NaN
# 1  01/02/2009 09:00                64.1                                   NaN
# 2  01/03/2009 09:00                 8.7                                   NaN
# 3  01/04/2009 09:00                28.0                                  26.9
# 4  01/05/2009 09:00                24.5                                  65.8
#
#    ALBUFEIRA DO ROXO (26I/02F)  ALCÁÇOVAS (23I/01C)  \
# 0                          NaN                111.4
# 1                          NaN                 56.9
# 2                          NaN                 25.9
# 3                          NaN                 23.8
# 4                          3.3                 18.9
#
#    BARRAGEM DE MAGOS (20E/01C)  BARRAGEM DE MEIMOA (12O/04C)  \
# 0                          NaN                           NaN
# 1                         71.4                           NaN
# 2                          4.7                           NaN
# 3                         40.7                          28.6
# 4                         30.0                          29.4
#
#    BARRAGEM DE ODIVELAS (24I/03C)  BARRAGEM MONTE DA ROCHA (27H/02C)  \
# 0                            90.5                               83.2
# 1                            50.2                               73.7
# 2                            18.1                               34.8
# 3                            48.9                               42.4
# 4                             7.5                               19.8
#
#    CAXARIAS (15F/02C)  ...  GRÂNDOLA (24F/01C)  \
# 0               145.1  ...                 NaN
# 1                65.6  ...                58.1
# 2                20.6  ...                 7.5
# 3                43.5  ...                30.2
# 4                33.3  ...                 3.8
#
#    LARANJAL (PONTE SÔR) (18I/01C)  MECA (19C/08C)  MOINHOLA (22F/03C)  \
# 0                           108.2            99.4                 NaN
# 1                            48.6            60.0                86.1
# 2                            11.6             9.5                13.0
# 3                            32.8            34.4                31.1
# 4                            20.9            31.1                11.8
#
#    MONTE DA CAPARICA (22B/01C)  PEDROGÃO (16F/04C)  SANTARÉM (ESA) (18E/01C)  \
# 0                          0.0               133.1                     135.8
# 1                          0.0                78.3                      90.5
# 2                          0.0                25.1                      16.1
# 3                         36.8                59.4                      46.4
# 4                         11.9                28.1                      20.7
#
#    SÃO JULIÃO DO TOJAL (20C/01C)  VIANA DO ALENTEJO (24I/01C)  \
# 0                          139.9                        117.7
# 1                           82.3                         60.7
# 2                           14.9                         20.4
# 3                           48.9                          1.7
# 4                           48.1                          9.5
#
#    VILA FRANCA DE XIRA (LEZÍRIA) (20D/01C)
# 0                                     34.9
# 1                                      2.1
# 2                                      0.1
# 3                                     38.0
# 4                                     35.1
#
# [5 rows x 22 columns]
# Index(['01/01/2009 09:00', '01/02/2009 09:00', '01/03/2009 09:00',
#        '01/04/2009 09:00', '01/05/2009 09:00', '01/06/2009 09:00',
#        '01/07/2009 09:00', '01/08/2009 09:00', '01/09/2009 09:00',
#        '01/10/2009 09:00', '01/11/2009 09:00', '01/12/2009 09:00'],
#       dtype='object', name='DATA')
# Index(['ABRANTES (17H/01C)', 'ALBUFEIRA DE PEGO DO ALTAR (23G/01F)',
#        'ALBUFEIRA DO ROXO (26I/02F)', 'ALCÁÇOVAS (23I/01C)',
#        'BARRAGEM DE MAGOS (20E/01C)', 'BARRAGEM DE MEIMOA (12O/04C)',
#        'BARRAGEM DE ODIVELAS (24I/03C)', 'BARRAGEM MONTE DA ROCHA (27H/02C)',
#        'CAXARIAS (15F/02C)', 'CERNACHE DE BONJARDIM (15H/01C)',
#        'COMPORTA (23E/01C)', 'GRÂNDOLA (24F/01C)',
#        'LARANJAL (PONTE SÔR) (18I/01C)', 'MECA (19C/08C)',
#        'MOINHOLA (22F/03C)', 'MONTE DA CAPARICA (22B/01C)',
#        'PEDROGÃO (16F/04C)', 'SANTARÉM (ESA) (18E/01C)',
#        'SÃO JULIÃO DO TOJAL (20C/01C)', 'VIANA DO ALENTEJO (24I/01C)',
#        'VILA FRANCA DE XIRA (LEZÍRIA) (20D/01C)'],
#       dtype='object')
